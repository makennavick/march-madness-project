# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
import pandas as pd
import tensorflow as tf

# Import pandas and read the charity_data.csv from the provided cloud URL.
import pandas as pd
bracket_df = pd.read_csv('Data_cleaning/barttorvik_all_years.csv')
bracket_df.head()
# Out:
#    Year  Seed     School  Round Finished  Conf   G   Rec  AdjOE  AdjDE  AdjNR  \
# 0  2008     1     Kansas             6.0   B12  33  30–3  121.1   85.9   35.2
# 1  2008     1    Memphis             5.0  CUSA  34  33–1  113.4   84.0   29.4
# 2  2008     1       UCLA             4.0   P10  33  30–3  116.4   87.2   29.2
# 3  2008     3  Wisconsin             2.0   B10  33  29–4  112.3   85.2   27.1
# 4  2008     2       Duke             1.0   ACC  32  27–5  117.3   89.0   28.3
#
#    ...   FTR  FTRD   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB
# 0  ...  37.5  30.8  54.8  40.9  39.9  34.0  29.2  38.1    69.5   9.9
# 1  ...  38.6  32.7  53.3  41.6  35.0  29.8  36.7  28.7    70.7   9.0
# 2  ...  38.0  25.7  52.9  46.8  33.8  34.2  28.1  27.9    66.2  10.7
# 3  ...  39.3  25.4  49.2  41.3  35.9  31.1  31.1  32.8    63.5   8.2
# 4  ...  40.4  32.0  51.8  47.1  38.4  32.8  39.1  24.8    73.7   8.9
#
# [5 rows x 27 columns]

# %%
#Exclude 2025 data from CSV

#Create Copy of Data
copy_df = bracket_df.copy()

#Create New Dataframe for all years except 2025
no_2025_df = copy_df.loc[(copy_df["Year"] != 2025)]

# %%
#Set Round Finished to Sweet Sixteen (2)
s_16_df = no_2025_df[no_2025_df['Round Finished'] >= 2]
# Out:
#       Year  Seed          School  Round Finished  Conf   G    Rec  AdjOE  \
# 0     2008     1          Kansas             6.0   B12  33   30–3  121.1
# 1     2008     1         Memphis             5.0  CUSA  34   33–1  113.4
# 2     2008     1            UCLA             4.0   P10  33   30–3  116.4
# 3     2008     3       Wisconsin             2.0   B10  33   29–4  112.3
# 5     2008     1  North Carolina             4.0   ACC  34   32–2  120.3
# ...    ...   ...             ...             ...   ...  ..    ...    ...
# 1023  2024     3        Illinois             3.0   B10  34   26–8  124.3
# 1025  2024     5         Gonzaga             2.0   WCC  31   24–7  120.6
# 1038  2024     5   San Diego St.             2.0   MWC  32  22–10  111.8
# 1040  2024     6         Clemson             3.0   ACC  32  21–11  117.2
# 1055  2024    11      N.C. State             4.0   ACC  36  22–14  113.6
#
#       AdjDE  AdjNR  ...   FTR  FTRD   2P%  2P%D   3P%  3P%D   3PR  3PRD  \
# 0      85.9   35.2  ...  37.5  30.8  54.8  40.9  39.9  34.0  29.2  38.1
# 1      84.0   29.4  ...  38.6  32.7  53.3  41.6  35.0  29.8  36.7  28.7
# 2      87.2   29.2  ...  38.0  25.7  52.9  46.8  33.8  34.2  28.1  27.9
# 3      85.2   27.1  ...  39.3  25.4  49.2  41.3  35.9  31.1  31.1  32.8
# 5      92.0   28.3  ...  39.1  25.5  51.2  47.0  37.8  33.2  22.2  34.8
# ...     ...    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1023  100.7   23.6  ...  37.8  27.1  54.7  46.6  34.9  34.3  38.3  27.9
# 1025   98.3   22.3  ...  31.5  25.8  58.3  45.1  35.5  34.0  31.4  36.9
# 1038   94.4   17.4  ...  37.5  33.3  51.6  48.3  31.3  30.5  37.8  40.5
# 1040   99.2   18.0  ...  30.6  31.2  54.4  47.1  35.4  34.0  40.2  40.6
# 1055  100.7   12.9  ...  32.5  31.9  50.1  49.5  34.6  34.9  33.5  35.3
#
#       Adj T.    WAB
# 0       69.5   9.90
# 1       70.7   9.00
# 2       66.2  10.70
# 3       63.5   8.20
# 5       75.1  11.90
# ...      ...    ...
# 1023    70.8   5.60
# 1025    70.1   2.40
# 1038    67.1   2.20
# 1040    67.2   1.00
# 1055    68.9  -0.42
#
# [256 rows x 27 columns]

# %%
#Create Dummies Dataframe
dummies_df = pd.get_dummies(no_2025_df)
dummies_df.head()
# Out:
#    Year  Seed  Round Finished   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%  \
# 0  2008     1             6.0  33  121.1   85.9   35.2   0.9810  56.3   44.8
# 1  2008     1             5.0  34  113.4   84.0   29.4   0.9692  53.0   42.5
# 2  2008     1             4.0  33  116.4   87.2   29.2   0.9653  52.3   48.0
# 3  2008     3             2.0  33  112.3   85.2   27.1   0.9599  50.6   43.1
# 4  2008     2             1.0  32  117.3   89.0   28.3   0.9597  54.1   47.6
#
#    ...  Rec_30–2  Rec_30–3  Rec_30–4  Rec_31–2  Rec_31–3  Rec_32–1  Rec_32–2  \
# 0  ...     False      True     False     False     False     False     False
# 1  ...     False     False     False     False     False     False     False
# 2  ...     False      True     False     False     False     False     False
# 3  ...     False     False     False     False     False     False     False
# 4  ...     False     False     False     False     False     False     False
#
#    Rec_33–0  Rec_33–1  Rec_34–0
# 0     False     False     False
# 1     False      True     False
# 2     False     False     False
# 3     False     False     False
# 4     False     False     False
#
# [5 rows x 464 columns]

# %%
#separate Data into features and target arrays
y = dummies_df["Round Finished"]
X = dummies_df.drop(columns="Round Finished")

#Split the data into training and testing dataset\
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#scale data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create Logistic Regression Model
lr_model = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
lr_model
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
lr_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
#Score Model  
print(f"Training Data Score: {lr_model.score(X_train, y_train)}")
print(f"Testing Data Score: {lr_model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.5290482076637825
# Testing Data Score: 0.5481481481481482
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
#Make Predictions
predictions = lr_model.predict(X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
results.value_counts()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# Prediction  Actual
# 0.0         0.0       144
#             1.0        55
#             2.0        26
#             3.0        13
# 1.0         2.0         6
# 0.0         4.0         5
# 1.0         4.0         5
#             1.0         4
#             3.0         3
#             6.0         3
# 0.0         5.0         2
# 1.0         0.0         2
# 0.0         6.0         1
# 1.0         5.0         1
# Name: count, dtype: int64

# %%
(only predicted 0 and 1, did not try to predict further appearances)
