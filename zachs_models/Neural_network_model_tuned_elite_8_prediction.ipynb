# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# Import pandas and read the charity_data.csv from the provided cloud URL.
import pandas as pd
bracket_df = pd.read_csv('../Data_cleaning/barttorvik_all_years.csv')
bracket_df.head()
# Out:
#    Year  Seed     School  Round Finished  Conf   G   Rec  AdjOE  AdjDE  AdjNR  \
# 0  2008     1     Kansas             6.0   B12  33  30–3  121.1   85.9   35.2
# 1  2008     1    Memphis             5.0  CUSA  34  33–1  113.4   84.0   29.4
# 2  2008     1       UCLA             4.0   P10  33  30–3  116.4   87.2   29.2
# 3  2008     3  Wisconsin             2.0   B10  33  29–4  112.3   85.2   27.1
# 4  2008     2       Duke             1.0   ACC  32  27–5  117.3   89.0   28.3
#
#    ...   FTR  FTRD   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB
# 0  ...  37.5  30.8  54.8  40.9  39.9  34.0  29.2  38.1    69.5   9.9
# 1  ...  38.6  32.7  53.3  41.6  35.0  29.8  36.7  28.7    70.7   9.0
# 2  ...  38.0  25.7  52.9  46.8  33.8  34.2  28.1  27.9    66.2  10.7
# 3  ...  39.3  25.4  49.2  41.3  35.9  31.1  31.1  32.8    63.5   8.2
# 4  ...  40.4  32.0  51.8  47.1  38.4  32.8  39.1  24.8    73.7   8.9
#
# [5 rows x 27 columns]

# %%
#Split Record into Wins and Losses
bracket_df[['Wins', 'Losses']] = bracket_df['Rec'].str.split('–', expand=True)

#Change Columns to Ints
bracket_df['Wins'] = bracket_df['Wins'].astype(int)
bracket_df['Losses'] = bracket_df['Losses'].astype(int)

#Drop Rec Column
clean_df = bracket_df.drop(columns=['Rec', 'School', 'Conf'])

clean_df.head()
# Out:
#    Year  Seed  Round Finished   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%  \
# 0  2008     1             6.0  33  121.1   85.9   35.2   0.9810  56.3   44.8
# 1  2008     1             5.0  34  113.4   84.0   29.4   0.9692  53.0   42.5
# 2  2008     1             4.0  33  116.4   87.2   29.2   0.9653  52.3   48.0
# 3  2008     3             2.0  33  112.3   85.2   27.1   0.9599  50.6   43.1
# 4  2008     2             1.0  32  117.3   89.0   28.3   0.9597  54.1   47.6
#
#    ...   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses
# 0  ...  54.8  40.9  39.9  34.0  29.2  38.1    69.5   9.9    30       3
# 1  ...  53.3  41.6  35.0  29.8  36.7  28.7    70.7   9.0    33       1
# 2  ...  52.9  46.8  33.8  34.2  28.1  27.9    66.2  10.7    30       3
# 3  ...  49.2  41.3  35.9  31.1  31.1  32.8    63.5   8.2    29       4
# 4  ...  51.8  47.1  38.4  32.8  39.1  24.8    73.7   8.9    27       5
#
# [5 rows x 26 columns]

# %%
#Exclude 2025 data from CSV

#Create Copy of Data
copy_df = clean_df.copy()

#Create New Dataframe for all years except 2025
no_2025_df = copy_df.loc[(clean_df["Year"] != 2025)]

# %%
#Use list comprehension to create Sweet 16 values

e_8 = [1 if x >= 3 else 0 for x in no_2025_df['Round Finished']]

#Assign list to column
no_2025_df['Elite 8'] = e_8
#Show Dataframe
no_2025_df.head()
# Out:
# /var/folders/f6/crwn6xns7ng5zdqghg60td240000gn/T/ipykernel_29216/1554374021.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2025_df['Elite 8'] = e_8
#    Year  Seed  Round Finished   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%  \
# 0  2008     1             6.0  33  121.1   85.9   35.2   0.9810  56.3   44.8
# 1  2008     1             5.0  34  113.4   84.0   29.4   0.9692  53.0   42.5
# 2  2008     1             4.0  33  116.4   87.2   29.2   0.9653  52.3   48.0
# 3  2008     3             2.0  33  112.3   85.2   27.1   0.9599  50.6   43.1
# 4  2008     2             1.0  32  117.3   89.0   28.3   0.9597  54.1   47.6
#
#    ...  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses  Elite 8
# 0  ...  40.9  39.9  34.0  29.2  38.1    69.5   9.9    30       3        1
# 1  ...  41.6  35.0  29.8  36.7  28.7    70.7   9.0    33       1        1
# 2  ...  46.8  33.8  34.2  28.1  27.9    66.2  10.7    30       3        1
# 3  ...  41.3  35.9  31.1  31.1  32.8    63.5   8.2    29       4        0
# 4  ...  47.1  38.4  32.8  39.1  24.8    73.7   8.9    27       5        0
#
# [5 rows x 27 columns]

# %%
#Drop Round Finished from DataFrame
elite_8_df = no_2025_df.drop(columns='Round Finished')

elite_8_df.head()
# Out:
#    Year  Seed   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%   TOR  ...  2P%D  \
# 0  2008     1  33  121.1   85.9   35.2   0.9810  56.3   44.8  18.7  ...  40.9
# 1  2008     1  34  113.4   84.0   29.4   0.9692  53.0   42.5  17.2  ...  41.6
# 2  2008     1  33  116.4   87.2   29.2   0.9653  52.3   48.0  18.8  ...  46.8
# 3  2008     3  33  112.3   85.2   27.1   0.9599  50.6   43.1  19.4  ...  41.3
# 4  2008     2  32  117.3   89.0   28.3   0.9597  54.1   47.6  18.2  ...  47.1
#
#     3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses  Elite 8
# 0  39.9  34.0  29.2  38.1    69.5   9.9    30       3        1
# 1  35.0  29.8  36.7  28.7    70.7   9.0    33       1        1
# 2  33.8  34.2  28.1  27.9    66.2  10.7    30       3        1
# 3  35.9  31.1  31.1  32.8    63.5   8.2    29       4        0
# 4  38.4  32.8  39.1  24.8    73.7   8.9    27       5        0
#
# [5 rows x 26 columns]

# %%
#Create Dummies Dataframe
dummies_df = pd.get_dummies(elite_8_df)
dummies_df.head()
# Out:
#    Year  Seed   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%   TOR  ...  2P%D  \
# 0  2008     1  33  121.1   85.9   35.2   0.9810  56.3   44.8  18.7  ...  40.9
# 1  2008     1  34  113.4   84.0   29.4   0.9692  53.0   42.5  17.2  ...  41.6
# 2  2008     1  33  116.4   87.2   29.2   0.9653  52.3   48.0  18.8  ...  46.8
# 3  2008     3  33  112.3   85.2   27.1   0.9599  50.6   43.1  19.4  ...  41.3
# 4  2008     2  32  117.3   89.0   28.3   0.9597  54.1   47.6  18.2  ...  47.1
#
#     3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses  Elite 8
# 0  39.9  34.0  29.2  38.1    69.5   9.9    30       3        1
# 1  35.0  29.8  36.7  28.7    70.7   9.0    33       1        1
# 2  33.8  34.2  28.1  27.9    66.2  10.7    30       3        1
# 3  35.9  31.1  31.1  32.8    63.5   8.2    29       4        0
# 4  38.4  32.8  39.1  24.8    73.7   8.9    27       5        0
#
# [5 rows x 26 columns]

# %%
#separate Data into features and target arrays
y = dummies_df["Elite 8"]
X = dummies_df.drop(columns="Elite 8")

#Split the data into training and testing dataset\
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=30,
        step=5), activation=activation, input_dim=25))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 15)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=5),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy", "precision", "recall"])

    return nn_model

# %%
#Import Keras Tuner
import keras_tuner as kt

#Create Tuner
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=30,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=50,validation_data=(X_test_scaled,y_test))

# %%
# Get top 3 model hyperparameters and print the values
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
# Out:
# {'activation': 'tanh', 'first_units': 26, 'num_layers': 3, 'units_0': 1, 'units_1': 1, 'units_2': 26, 'units_3': 11, 'units_4': 11, 'units_5': 16, 'units_6': 16, 'units_7': 26, 'units_8': 11, 'units_9': 6, 'units_10': 6, 'units_11': 21, 'units_12': 11, 'units_13': 21, 'units_14': 6, 'tuner/epochs': 10, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 21, 'num_layers': 8, 'units_0': 16, 'units_1': 1, 'units_2': 6, 'units_3': 1, 'units_4': 16, 'units_5': 26, 'units_6': 26, 'units_7': 26, 'units_8': 26, 'units_9': 6, 'units_10': 21, 'units_11': 6, 'units_12': 16, 'units_13': 26, 'units_14': 11, 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 3, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 11, 'num_layers': 7, 'units_0': 26, 'units_1': 16, 'units_2': 26, 'units_3': 26, 'units_4': 16, 'units_5': 6, 'units_6': 11, 'units_7': 16, 'units_8': 1, 'units_9': 16, 'units_10': 26, 'units_11': 16, 'units_12': 16, 'units_13': 11, 'units_14': 21, 'tuner/epochs': 30, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}

# %%
# Evaluate the top 3 models against the test dataset
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy, model_precision, model_recall = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 42 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 9/9 - 0s - 18ms/step - accuracy: 0.8630 - loss: 0.3620 - precision: 0.4583 - recall: 0.6667
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 38 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Loss: 0.3619774281978607, Accuracy: 0.8629629611968994, Precision: 0.4583333432674408, Recall: 0.6666666865348816
# 9/9 - 0s - 20ms/step - accuracy: 0.8296 - loss: 0.3501 - precision: 0.3934 - recall: 0.7273
# Loss: 0.3500753343105316, Accuracy: 0.8296296000480652, Precision: 0.39344263076782227, Recall: 0.7272727489471436
# 9/9 - 0s - 19ms/step - accuracy: 0.8259 - loss: 0.3788 - precision: 0.3833 - recall: 0.6970
# Loss: 0.378823459148407, Accuracy: 0.8259259462356567, Precision: 0.38333332538604736, Recall: 0.6969696879386902

# %%
#Get summary of the best model and display
best_summary = tuner.get_best_hyperparameters(1)[0]
best_summary.values
# Out:
# {'activation': 'tanh',
#  'first_units': 26,
#  'num_layers': 3,
#  'units_0': 1,
#  'units_1': 1,
#  'units_2': 26,
#  'units_3': 11,
#  'units_4': 11,
#  'units_5': 16,
#  'units_6': 16,
#  'units_7': 26,
#  'units_8': 11,
#  'units_9': 6,
#  'units_10': 6,
#  'units_11': 21,
#  'units_12': 11,
#  'units_13': 21,
#  'units_14': 6,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 1,
#  'tuner/round': 0}

# %%
#Run the tuner and fit the model
final_tune = tuner.hypermodel.build(best_summary)
final_tune.fit(X_train_scaled,y_train,epochs=70)
# Out:
# Epoch 1/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step - accuracy: 0.6152 - loss: 0.6738 - precision: 0.1316 - recall: 0.4187
# Epoch 2/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - accuracy: 0.7877 - loss: 0.5913 - precision: 0.2120 - recall: 0.3099
# Epoch 3/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.8322 - loss: 0.5033 - precision: 0.2669 - recall: 0.2494
# Epoch 4/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.8622 - loss: 0.4171 - precision: 0.2785 - recall: 0.0874
# Epoch 5/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - accuracy: 0.8911 - loss: 0.3318 - precision: 0.5954 - recall: 0.0973
# Epoch 6/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.8937 - loss: 0.2899 - precision: 0.4189 - recall: 0.1269
# Epoch 7/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - accuracy: 0.9000 - loss: 0.2719 - precision: 0.4924 - recall: 0.2846
# Epoch 8/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.8840 - loss: 0.2833 - precision: 0.6248 - recall: 0.4075
# Epoch 9/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.9030 - loss: 0.2467 - precision: 0.6495 - recall: 0.3321
# Epoch 10/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.8964 - loss: 0.2594 - precision: 0.6035 - recall: 0.4223
# Epoch 11/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.9005 - loss: 0.2618 - precision: 0.6911 - recall: 0.4283
# Epoch 12/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9015 - loss: 0.2214 - precision: 0.5958 - recall: 0.4686
# Epoch 13/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.8892 - loss: 0.2637 - precision: 0.6693 - recall: 0.3740
# Epoch 14/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.9189 - loss: 0.2256 - precision: 0.7435 - recall: 0.5001
# Epoch 15/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.8977 - loss: 0.2350 - precision: 0.6030 - recall: 0.4743
# Epoch 16/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 0.9219 - loss: 0.2079 - precision: 0.6591 - recall: 0.4035
# Epoch 17/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - accuracy: 0.8989 - loss: 0.2450 - precision: 0.6605 - recall: 0.5315
# Epoch 18/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - accuracy: 0.9037 - loss: 0.2233 - precision: 0.6096 - recall: 0.4532
# Epoch 19/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.8854 - loss: 0.2308 - precision: 0.5078 - recall: 0.4565
# Epoch 20/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.9091 - loss: 0.2141 - precision: 0.6672 - recall: 0.4601
# Epoch 21/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.8915 - loss: 0.2447 - precision: 0.5919 - recall: 0.4526
# Epoch 22/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - accuracy: 0.9144 - loss: 0.2054 - precision: 0.6475 - recall: 0.4950
# Epoch 23/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.9187 - loss: 0.2031 - precision: 0.6838 - recall: 0.5564
# Epoch 24/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - accuracy: 0.9056 - loss: 0.2321 - precision: 0.6668 - recall: 0.4832
# Epoch 25/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - accuracy: 0.9069 - loss: 0.2269 - precision: 0.6944 - recall: 0.5369
# Epoch 26/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.9106 - loss: 0.2096 - precision: 0.6228 - recall: 0.5330
# Epoch 27/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.9157 - loss: 0.2087 - precision: 0.7055 - recall: 0.5817
# Epoch 28/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.9014 - loss: 0.2243 - precision: 0.6121 - recall: 0.4685
# Epoch 29/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.9115 - loss: 0.2131 - precision: 0.6818 - recall: 0.5368
# Epoch 30/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.9182 - loss: 0.1907 - precision: 0.6475 - recall: 0.5108
# Epoch 31/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.9195 - loss: 0.2159 - precision: 0.7133 - recall: 0.6051
# Epoch 32/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.9185 - loss: 0.2183 - precision: 0.7474 - recall: 0.5403
# Epoch 33/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - accuracy: 0.9234 - loss: 0.2142 - precision: 0.8039 - recall: 0.5466
# Epoch 34/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.9302 - loss: 0.1705 - precision: 0.7173 - recall: 0.6027
# Epoch 35/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.9441 - loss: 0.1788 - precision: 0.8441 - recall: 0.6260
# Epoch 36/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.9315 - loss: 0.2015 - precision: 0.7716 - recall: 0.6091
# Epoch 37/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.9317 - loss: 0.2223 - precision: 0.7546 - recall: 0.7423
# Epoch 38/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - accuracy: 0.9302 - loss: 0.2206 - precision: 0.8122 - recall: 0.5847
# Epoch 39/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.9391 - loss: 0.1650 - precision: 0.7346 - recall: 0.5865
# Epoch 40/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 0.9452 - loss: 0.1738 - precision: 0.8404 - recall: 0.6763
# Epoch 41/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.9506 - loss: 0.1684 - precision: 0.8834 - recall: 0.6837
# Epoch 42/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.9490 - loss: 0.1683 - precision: 0.8187 - recall: 0.6628
# Epoch 43/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.9448 - loss: 0.1915 - precision: 0.8121 - recall: 0.7421
# Epoch 44/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - accuracy: 0.9450 - loss: 0.1763 - precision: 0.8331 - recall: 0.6982
# Epoch 45/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 0.9275 - loss: 0.2019 - precision: 0.7861 - recall: 0.5621
# Epoch 46/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - accuracy: 0.9660 - loss: 0.1346 - precision: 0.8676 - recall: 0.8300
# Epoch 47/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.9514 - loss: 0.1654 - precision: 0.8443 - recall: 0.7410
# Epoch 48/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.9475 - loss: 0.1882 - precision: 0.8879 - recall: 0.6788
# Epoch 49/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.9640 - loss: 0.1326 - precision: 0.9072 - recall: 0.7701
# Epoch 50/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.9564 - loss: 0.1518 - precision: 0.9011 - recall: 0.7032
# Epoch 51/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - accuracy: 0.9584 - loss: 0.1592 - precision: 0.8964 - recall: 0.7618
# Epoch 52/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.9499 - loss: 0.1703 - precision: 0.8708 - recall: 0.7021
# Epoch 53/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - accuracy: 0.9580 - loss: 0.1492 - precision: 0.8207 - recall: 0.8210
# Epoch 54/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9539 - loss: 0.1792 - precision: 0.8403 - recall: 0.7172
# Epoch 55/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.9702 - loss: 0.1425 - precision: 0.9046 - recall: 0.8165
# Epoch 56/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.9587 - loss: 0.1518 - precision: 0.8630 - recall: 0.7481
# Epoch 57/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.9605 - loss: 0.1468 - precision: 0.8754 - recall: 0.7865
# Epoch 58/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - accuracy: 0.9655 - loss: 0.1512 - precision: 0.8793 - recall: 0.8051
# Epoch 59/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - accuracy: 0.9548 - loss: 0.1825 - precision: 0.8722 - recall: 0.7173
# Epoch 60/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.9589 - loss: 0.1698 - precision: 0.8775 - recall: 0.7801
# Epoch 61/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - accuracy: 0.9511 - loss: 0.1783 - precision: 0.8575 - recall: 0.7081
# Epoch 62/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.9577 - loss: 0.1647 - precision: 0.8869 - recall: 0.7476
# Epoch 63/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.9646 - loss: 0.1471 - precision: 0.9201 - recall: 0.7702
# Epoch 64/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9683 - loss: 0.1279 - precision: 0.8891 - recall: 0.8438
# Epoch 65/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - accuracy: 0.9732 - loss: 0.0984 - precision: 0.8955 - recall: 0.8749
# Epoch 66/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - accuracy: 0.9681 - loss: 0.1377 - precision: 0.9007 - recall: 0.8139
# Epoch 67/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - accuracy: 0.9700 - loss: 0.1145 - precision: 0.9035 - recall: 0.8344
# Epoch 68/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - accuracy: 0.9669 - loss: 0.1214 - precision: 0.8890 - recall: 0.8206
# Epoch 69/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - accuracy: 0.9787 - loss: 0.1141 - precision: 0.9436 - recall: 0.8583
# Epoch 70/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.9761 - loss: 0.1134 - precision: 0.9564 - recall: 0.8321

# %%
#Evaluate the effectiveness of the model
final_tune.evaluate(X_test_scaled, y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8550 - loss: 0.4183 - precision: 0.4664 - recall: 0.3496
# [0.4168594777584076,
#  0.8592592477798462,
#  0.4193548262119293,
#  0.39393940567970276]

# %%
#Create dataframe for just 2025
df_2025 = copy_df.loc[(copy_df["Year"] == 2025)]
df_2025
# Out:
#       Year  Seed  Round Finished   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  \
# 1079  2025     1             NaN  34  124.6   87.6   37.0   0.9830  52.7
# 1080  2025     1             NaN  34  127.4   90.8   36.6   0.9800  57.4
# 1081  2025     1             NaN  33  129.7   93.4   36.3   0.9775  55.7
# 1082  2025     1             NaN  34  127.0   94.0   33.0   0.9694  55.0
# 1083  2025     2             NaN  33  127.1   96.2   30.9   0.9606  56.3
# ...    ...   ...             ...  ..    ...    ...    ...      ...   ...
# 1142  2025    16             NaN  30  101.0  105.6   -4.6   0.3736  48.9
# 1143  2025    16             NaN  32  101.5  108.0   -6.5   0.3309  51.8
# 1144  2025    16             NaN  33   99.1  107.4   -8.3   0.2840  51.0
# 1145  2025    16             NaN  33  101.3  110.7   -9.4   0.2662  47.1
# 1146  2025    16             NaN  30   99.9  112.1  -12.2   0.2092  51.6
#
#       EFGD%  ...   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  \
# 1079   44.9  ...  49.0  43.9  39.8  30.9  34.5  43.1    62.2  11.6    30
# 1080   44.5  ...  58.0  43.4  37.7  30.9  45.4  37.9    66.5   9.4    31
# 1081   46.0  ...  56.1  47.2  36.8  29.2  40.6  34.8    68.5  12.5    28
# 1082   45.3  ...  56.4  45.9  35.5  29.6  43.6  37.3    70.3  11.1    30
# 1083   47.9  ...  59.7  48.8  35.0  30.8  46.2  35.1    75.4   9.8    25
# ...     ...  ...   ...   ...   ...   ...   ...   ...     ...   ...   ...
# 1142   47.5  ...  47.8  46.3  34.0  33.0  36.3  38.6    66.6  -7.8    19
# 1143   52.1  ...  51.1  53.1  35.1  33.6  44.8  35.7    64.2  -8.3    20
# 1144   48.0  ...  50.1  48.7  34.9  31.4  41.0  44.5    68.1  -8.2    21
# 1145   50.3  ...  45.4  50.4  32.9  33.4  42.9  39.5    68.4 -10.2    18
# 1146   51.3  ...  52.6  53.4  33.4  32.3  41.9  43.2    67.9 -12.2    13
#
#       Losses
# 1079       4
# 1080       3
# 1081       5
# 1082       4
# 1083       8
# ...      ...
# 1142      11
# 1143      12
# 1144      12
# 1145      15
# 1146      17
#
# [68 rows x 26 columns]

# %%
#Drop the round finished column
clean_2025 = df_2025.drop(columns='Round Finished')
clean_2025.head()
# Out:
#       Year  Seed   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%   TOR  ...  \
# 1079  2025     1  34  124.6   87.6   37.0   0.9830  52.7   44.9  14.6  ...
# 1080  2025     1  34  127.4   90.8   36.6   0.9800  57.4   44.5  14.4  ...
# 1081  2025     1  33  129.7   93.4   36.3   0.9775  55.7   46.0  13.4  ...
# 1082  2025     1  34  127.0   94.0   33.0   0.9694  55.0   45.3  15.0  ...
# 1083  2025     2  33  127.1   96.2   30.9   0.9606  56.3   47.9  16.7  ...
#
#        2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses
# 1079  49.0  43.9  39.8  30.9  34.5  43.1    62.2  11.6    30       4
# 1080  58.0  43.4  37.7  30.9  45.4  37.9    66.5   9.4    31       3
# 1081  56.1  47.2  36.8  29.2  40.6  34.8    68.5  12.5    28       5
# 1082  56.4  45.9  35.5  29.6  43.6  37.3    70.3  11.1    30       4
# 1083  59.7  48.8  35.0  30.8  46.2  35.1    75.4   9.8    25       8
#
# [5 rows x 25 columns]

# %%
# Create a StandardScaler instances
scaler_2025 = StandardScaler()

# Fit the StandardScaler
scaler25 = scaler.fit(clean_2025)

# Scale the data
scaled_2025 = scaler25.transform(clean_2025)

# %%
#Use model to predict 2025 Elite 8 probabilities
prediction_2025 = final_tune.predict(scaled_2025)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
#Create new Dataframe to Pull team names From
name_df = bracket_df.copy()

names_2025 = name_df.loc[(bracket_df["Year"] == 2025)]
names_2025.head(68)
# Out:
#       Year  Seed            School  Round Finished  Conf   G    Rec  AdjOE  \
# 1079  2025     1           Houston             NaN   B12  34   30–4  124.6
# 1080  2025     1              Duke             NaN   ACC  34   31–3  127.4
# 1081  2025     1            Auburn             NaN   SEC  33   28–5  129.7
# 1082  2025     1           Florida             NaN   SEC  34   30–4  127.0
# 1083  2025     2           Alabama             NaN   SEC  33   25–8  127.1
# ...    ...   ...               ...             ...   ...  ..    ...    ...
# 1142  2025    16  SIU Edwardsville             NaN   OVC  30  19–11  101.0
# 1143  2025    16          American             NaN   Pat  32  20–12  101.5
# 1144  2025    16  Mount St. Mary's             NaN  MAAC  33  21–12   99.1
# 1145  2025    16       Alabama St.             NaN  SWAC  33  18–15  101.3
# 1146  2025    16     Saint Francis             NaN   NEC  30  13–17   99.9
#
#       AdjDE  AdjNR  ...   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  \
# 1079   87.6   37.0  ...  49.0  43.9  39.8  30.9  34.5  43.1    62.2  11.6
# 1080   90.8   36.6  ...  58.0  43.4  37.7  30.9  45.4  37.9    66.5   9.4
# 1081   93.4   36.3  ...  56.1  47.2  36.8  29.2  40.6  34.8    68.5  12.5
# 1082   94.0   33.0  ...  56.4  45.9  35.5  29.6  43.6  37.3    70.3  11.1
# 1083   96.2   30.9  ...  59.7  48.8  35.0  30.8  46.2  35.1    75.4   9.8
# ...     ...    ...  ...   ...   ...   ...   ...   ...   ...     ...   ...
# 1142  105.6   -4.6  ...  47.8  46.3  34.0  33.0  36.3  38.6    66.6  -7.8
# 1143  108.0   -6.5  ...  51.1  53.1  35.1  33.6  44.8  35.7    64.2  -8.3
# 1144  107.4   -8.3  ...  50.1  48.7  34.9  31.4  41.0  44.5    68.1  -8.2
# 1145  110.7   -9.4  ...  45.4  50.4  32.9  33.4  42.9  39.5    68.4 -10.2
# 1146  112.1  -12.2  ...  52.6  53.4  33.4  32.3  41.9  43.2    67.9 -12.2
#
#       Wins  Losses
# 1079    30       4
# 1080    31       3
# 1081    28       5
# 1082    30       4
# 1083    25       8
# ...    ...     ...
# 1142    19      11
# 1143    20      12
# 1144    21      12
# 1145    18      15
# 1146    13      17
#
# [68 rows x 29 columns]

# %%
#Turn nested list into a flattened list
flattened_prediction = []
for sublist in prediction_2025:
    for item in sublist:
        flattened_prediction.append(item)

#sorted_predictions = sorted(flattened_prediction, reverse=True)

# %%
#Create Dataframe with Names and Predictions

#Create dictionary of Schools and Prediction
data = {
    'School': names_2025['School'],
    'Probability': flattened_prediction
}

#Create DataFrame
df = pd.DataFrame(data)

#Sort Dataframe
df_sorted = df.sort_values(by='Probability', ascending=False)

#Display the dataframe
df_sorted.head()
# Out:
#                School  Probability
# 1091        Wisconsin     0.954171
# 1082          Florida     0.882813
# 1084        Tennessee     0.874319
# 1079          Houston     0.840610
# 1086         Iowa St.     0.826488
# 1080             Duke     0.805116
# 1089          Gonzaga     0.725011
# 1094         Kentucky     0.602942
# 1087          Arizona     0.475871
# 1085       Texas Tech     0.397062
# 1090     Michigan St.     0.176322
# 1092       St. John's     0.148676
# 1088         Maryland     0.147981
# 1083          Alabama     0.114211
# 1081           Auburn     0.111074
# 1100       Louisville     0.041009
# 1126            Drake     0.030628
# 1109  Mississippi St.     0.027817
# 1103     Saint Mary's     0.026511
# 1097           Purdue     0.021304
# 1105        Marquette     0.020946
# 1118            Texas     0.020484
# 1107      Mississippi     0.018673
# 1101          Clemson     0.018060
# 1095           Kansas     0.017117
# 1096         Illinois     0.016982
# 1113           Oregon     0.015991
# 1093              BYU     0.015445
# 1114   North Carolina     0.013965
# 1104         Michigan     0.013564
# 1116           Xavier     0.012221
# 1099        Texas A&M     0.011631

# %%
#Plotting Dataframe

#Create new dataframe
df_sorted2 = df_sorted.sort_values(by='Probability', ascending=False)

#Grab the school and probability to plot
sorted_school = df_sorted2['School']
sorted_probability = df_sorted2['Probability']

#Plot bar graph and set size
plt.figure(figsize=(25,8))
plt.bar(sorted_school, sorted_probability)

#Set Xticks to display names vertically
plt.xticks(rotation=90)

#Set X and Y limits
plt.xlim(-0.75, len(sorted_school))
plt.ylim(0, max(sorted_probability)+.05)

#Set title and axes labels
plt.title("Likelihood of Making Elite 8")
plt.xlabel("School")
plt.ylabel("Model Probability to make the Elite 8")

#Plot the graph
plt.show()
