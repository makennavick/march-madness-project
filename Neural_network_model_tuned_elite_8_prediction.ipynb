# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# Import pandas and read the charity_data.csv from the provided cloud URL.
import pandas as pd
bracket_df = pd.read_csv('Data_cleaning/barttorvik_all_years.csv')
bracket_df.head()
# Out:
#    Year  Seed     School  Round Finished  Conf   G   Rec  AdjOE  AdjDE  AdjNR  \
# 0  2008     1     Kansas             6.0   B12  33  30–3  121.1   85.9   35.2
# 1  2008     1    Memphis             5.0  CUSA  34  33–1  113.4   84.0   29.4
# 2  2008     1       UCLA             4.0   P10  33  30–3  116.4   87.2   29.2
# 3  2008     3  Wisconsin             2.0   B10  33  29–4  112.3   85.2   27.1
# 4  2008     2       Duke             1.0   ACC  32  27–5  117.3   89.0   28.3
#
#    ...   FTR  FTRD   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB
# 0  ...  37.5  30.8  54.8  40.9  39.9  34.0  29.2  38.1    69.5   9.9
# 1  ...  38.6  32.7  53.3  41.6  35.0  29.8  36.7  28.7    70.7   9.0
# 2  ...  38.0  25.7  52.9  46.8  33.8  34.2  28.1  27.9    66.2  10.7
# 3  ...  39.3  25.4  49.2  41.3  35.9  31.1  31.1  32.8    63.5   8.2
# 4  ...  40.4  32.0  51.8  47.1  38.4  32.8  39.1  24.8    73.7   8.9
#
# [5 rows x 27 columns]

# %%
#Split Record into Wins and Losses
bracket_df[['Wins', 'Losses']] = bracket_df['Rec'].str.split('–', expand=True)

#Change Columns to Ints
bracket_df['Wins'] = bracket_df['Wins'].astype(int)
bracket_df['Losses'] = bracket_df['Losses'].astype(int)

#Drop Rec Column
clean_df = bracket_df.drop(columns=['Rec', 'School', 'Conf'])

clean_df.head()
# Out:
#    Year  Seed  Round Finished   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%  \
# 0  2008     1             6.0  33  121.1   85.9   35.2   0.9810  56.3   44.8
# 1  2008     1             5.0  34  113.4   84.0   29.4   0.9692  53.0   42.5
# 2  2008     1             4.0  33  116.4   87.2   29.2   0.9653  52.3   48.0
# 3  2008     3             2.0  33  112.3   85.2   27.1   0.9599  50.6   43.1
# 4  2008     2             1.0  32  117.3   89.0   28.3   0.9597  54.1   47.6
#
#    ...   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses
# 0  ...  54.8  40.9  39.9  34.0  29.2  38.1    69.5   9.9    30       3
# 1  ...  53.3  41.6  35.0  29.8  36.7  28.7    70.7   9.0    33       1
# 2  ...  52.9  46.8  33.8  34.2  28.1  27.9    66.2  10.7    30       3
# 3  ...  49.2  41.3  35.9  31.1  31.1  32.8    63.5   8.2    29       4
# 4  ...  51.8  47.1  38.4  32.8  39.1  24.8    73.7   8.9    27       5
#
# [5 rows x 26 columns]

# %%
#Exclude 2025 data from CSV

#Create Copy of Data
copy_df = clean_df.copy()

#Create New Dataframe for all years except 2025
no_2025_df = copy_df.loc[(clean_df["Year"] != 2025)]

# %%
#Use list comprehension to create Sweet 16 values

e_8 = [1 if x >= 3 else 0 for x in no_2025_df['Round Finished']]

#Assign list to column
no_2025_df['Elite 8'] = e_8
#Show Dataframe
no_2025_df.head()
# Out:
# /var/folders/f6/crwn6xns7ng5zdqghg60td240000gn/T/ipykernel_20398/1554374021.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_2025_df['Elite 8'] = e_8
#    Year  Seed  Round Finished   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%  \
# 0  2008     1             6.0  33  121.1   85.9   35.2   0.9810  56.3   44.8
# 1  2008     1             5.0  34  113.4   84.0   29.4   0.9692  53.0   42.5
# 2  2008     1             4.0  33  116.4   87.2   29.2   0.9653  52.3   48.0
# 3  2008     3             2.0  33  112.3   85.2   27.1   0.9599  50.6   43.1
# 4  2008     2             1.0  32  117.3   89.0   28.3   0.9597  54.1   47.6
#
#    ...  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses  Elite 8
# 0  ...  40.9  39.9  34.0  29.2  38.1    69.5   9.9    30       3        1
# 1  ...  41.6  35.0  29.8  36.7  28.7    70.7   9.0    33       1        1
# 2  ...  46.8  33.8  34.2  28.1  27.9    66.2  10.7    30       3        1
# 3  ...  41.3  35.9  31.1  31.1  32.8    63.5   8.2    29       4        0
# 4  ...  47.1  38.4  32.8  39.1  24.8    73.7   8.9    27       5        0
#
# [5 rows x 27 columns]

# %%
#Drop Round Finished from DataFrame
elite_8_df = no_2025_df.drop(columns='Round Finished')

elite_8_df.head()
# Out:
#    Year  Seed   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%   TOR  ...  2P%D  \
# 0  2008     1  33  121.1   85.9   35.2   0.9810  56.3   44.8  18.7  ...  40.9
# 1  2008     1  34  113.4   84.0   29.4   0.9692  53.0   42.5  17.2  ...  41.6
# 2  2008     1  33  116.4   87.2   29.2   0.9653  52.3   48.0  18.8  ...  46.8
# 3  2008     3  33  112.3   85.2   27.1   0.9599  50.6   43.1  19.4  ...  41.3
# 4  2008     2  32  117.3   89.0   28.3   0.9597  54.1   47.6  18.2  ...  47.1
#
#     3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses  Elite 8
# 0  39.9  34.0  29.2  38.1    69.5   9.9    30       3        1
# 1  35.0  29.8  36.7  28.7    70.7   9.0    33       1        1
# 2  33.8  34.2  28.1  27.9    66.2  10.7    30       3        1
# 3  35.9  31.1  31.1  32.8    63.5   8.2    29       4        0
# 4  38.4  32.8  39.1  24.8    73.7   8.9    27       5        0
#
# [5 rows x 26 columns]

# %%
#Create Dummies Dataframe
dummies_df = pd.get_dummies(elite_8_df)
dummies_df.head()
# Out:
#    Year  Seed   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%   TOR  ...  2P%D  \
# 0  2008     1  33  121.1   85.9   35.2   0.9810  56.3   44.8  18.7  ...  40.9
# 1  2008     1  34  113.4   84.0   29.4   0.9692  53.0   42.5  17.2  ...  41.6
# 2  2008     1  33  116.4   87.2   29.2   0.9653  52.3   48.0  18.8  ...  46.8
# 3  2008     3  33  112.3   85.2   27.1   0.9599  50.6   43.1  19.4  ...  41.3
# 4  2008     2  32  117.3   89.0   28.3   0.9597  54.1   47.6  18.2  ...  47.1
#
#     3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses  Elite 8
# 0  39.9  34.0  29.2  38.1    69.5   9.9    30       3        1
# 1  35.0  29.8  36.7  28.7    70.7   9.0    33       1        1
# 2  33.8  34.2  28.1  27.9    66.2  10.7    30       3        1
# 3  35.9  31.1  31.1  32.8    63.5   8.2    29       4        0
# 4  38.4  32.8  39.1  24.8    73.7   8.9    27       5        0
#
# [5 rows x 26 columns]

# %%
#separate Data into features and target arrays
y = dummies_df["Elite 8"]
X = dummies_df.drop(columns="Elite 8")

#Split the data into training and testing dataset\
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh'])

    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=30,
        step=5), activation=activation, input_dim=25))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 15)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=5),
            activation=activation))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy", "precision", "recall"])

    return nn_model

# %%
#Import Keras Tuner
import keras_tuner as kt

#Create Tuner
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=30,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from ./untitled_project/tuner0.json

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=50,validation_data=(X_test_scaled,y_test))

# %%
# Get top 3 model hyperparameters and print the values
top_hyper = tuner.get_best_hyperparameters(3)
for param in top_hyper:
    print(param.values)
# Out:
# {'activation': 'tanh', 'first_units': 11, 'num_layers': 2, 'units_0': 16, 'units_1': 6, 'units_2': 21, 'units_3': 11, 'units_4': 21, 'tuner/epochs': 20, 'tuner/initial_epoch': 7, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0045'}
# {'activation': 'tanh', 'first_units': 16, 'num_layers': 5, 'units_0': 26, 'units_1': 26, 'units_2': 1, 'units_3': 11, 'units_4': 26, 'tuner/epochs': 3, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 16, 'num_layers': 5, 'units_0': 26, 'units_1': 26, 'units_2': 1, 'units_3': 11, 'units_4': 26, 'tuner/epochs': 7, 'tuner/initial_epoch': 3, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0011'}

# %%
# Evaluate the top 3 models against the test dataset
top_model = tuner.get_best_models(3)
for model in top_model:
    model_loss, model_accuracy, model_precision, model_recall = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}, Precision: {model_precision}, Recall: {model_recall}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 30 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 9/9 - 0s - 18ms/step - accuracy: 0.8407 - loss: 0.3590 - precision: 0.4074 - recall: 0.6667
# Loss: 0.35904666781425476, Accuracy: 0.8407407402992249, Precision: 0.40740740299224854, Recall: 0.6666666865348816
# 9/9 - 0s - 19ms/step - accuracy: 0.8370 - loss: 0.3808 - precision: 0.4035 - recall: 0.6970
# Loss: 0.3808307945728302, Accuracy: 0.8370370268821716, Precision: 0.4035087823867798, Recall: 0.6969696879386902
# 9/9 - 0s - 19ms/step - accuracy: 0.8222 - loss: 0.3704 - precision: 0.3770 - recall: 0.6970
# Loss: 0.3703703284263611, Accuracy: 0.8222222328186035, Precision: 0.37704917788505554, Recall: 0.6969696879386902

# %%
best_summary = tuner.get_best_hyperparameters(1)[0]
best_summary.values
# Out:
# {'activation': 'tanh',
#  'first_units': 11,
#  'num_layers': 2,
#  'units_0': 16,
#  'units_1': 6,
#  'units_2': 21,
#  'units_3': 11,
#  'units_4': 21,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 1,
#  'tuner/round': 1,
#  'tuner/trial_id': '0045'}

# %%
final_tune = tuner.hypermodel.build(best_summary)
final_tune.fit(X_train_scaled,y_train,epochs=70)
# Out:
# Epoch 1/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 0.5950 - loss: 0.6854 - precision: 0.1662 - recall: 0.6644
# Epoch 2/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.7010 - loss: 0.6035 - precision: 0.2432 - recall: 0.7252
# Epoch 3/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.7553 - loss: 0.5470 - precision: 0.2823 - recall: 0.5999
# Epoch 4/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - accuracy: 0.8326 - loss: 0.4825 - precision: 0.4292 - recall: 0.5290
# Epoch 5/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.8780 - loss: 0.4195 - precision: 0.5856 - recall: 0.2336
# Epoch 6/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - accuracy: 0.8960 - loss: 0.3449 - precision: 0.5940 - recall: 0.2265
# Epoch 7/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - accuracy: 0.8985 - loss: 0.3208 - precision: 0.6309 - recall: 0.1940
# Epoch 8/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.8913 - loss: 0.3037 - precision: 0.6638 - recall: 0.2418
# Epoch 9/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.8934 - loss: 0.2867 - precision: 0.6536 - recall: 0.2396
# Epoch 10/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - accuracy: 0.9027 - loss: 0.2716 - precision: 0.7341 - recall: 0.3062
# Epoch 11/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.9062 - loss: 0.2525 - precision: 0.7293 - recall: 0.3168
# Epoch 12/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.8976 - loss: 0.2708 - precision: 0.7470 - recall: 0.3308
# Epoch 13/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - accuracy: 0.9148 - loss: 0.2322 - precision: 0.7926 - recall: 0.3246
# Epoch 14/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.9015 - loss: 0.2432 - precision: 0.7556 - recall: 0.3948
# Epoch 15/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - accuracy: 0.9236 - loss: 0.2269 - precision: 0.7936 - recall: 0.3344
# Epoch 16/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.9150 - loss: 0.2363 - precision: 0.7064 - recall: 0.3871
# Epoch 17/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.9048 - loss: 0.2345 - precision: 0.6902 - recall: 0.4534
# Epoch 18/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.9186 - loss: 0.2321 - precision: 0.8839 - recall: 0.4474
# Epoch 19/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.9145 - loss: 0.2273 - precision: 0.7375 - recall: 0.3819
# Epoch 20/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.9278 - loss: 0.2084 - precision: 0.7831 - recall: 0.5320
# Epoch 21/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.9308 - loss: 0.2002 - precision: 0.8161 - recall: 0.5084
# Epoch 22/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.9095 - loss: 0.2282 - precision: 0.7089 - recall: 0.4447
# Epoch 23/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.9341 - loss: 0.2022 - precision: 0.8219 - recall: 0.5461
# Epoch 24/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.9150 - loss: 0.2086 - precision: 0.7400 - recall: 0.4716
# Epoch 25/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.9027 - loss: 0.2273 - precision: 0.6295 - recall: 0.4566
# Epoch 26/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.9180 - loss: 0.2181 - precision: 0.7336 - recall: 0.5031
# Epoch 27/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - accuracy: 0.9231 - loss: 0.2038 - precision: 0.8633 - recall: 0.4586
# Epoch 28/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.9248 - loss: 0.2166 - precision: 0.8210 - recall: 0.4928
# Epoch 29/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.9324 - loss: 0.1754 - precision: 0.7994 - recall: 0.5361
# Epoch 30/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.9043 - loss: 0.2213 - precision: 0.7147 - recall: 0.4618
# Epoch 31/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - accuracy: 0.9303 - loss: 0.1883 - precision: 0.8393 - recall: 0.4843
# Epoch 32/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.9267 - loss: 0.1974 - precision: 0.7563 - recall: 0.4863
# Epoch 33/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - accuracy: 0.9243 - loss: 0.1939 - precision: 0.7431 - recall: 0.5241
# Epoch 34/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.9332 - loss: 0.1920 - precision: 0.8168 - recall: 0.5484
# Epoch 35/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.9256 - loss: 0.1917 - precision: 0.8012 - recall: 0.5121
# Epoch 36/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - accuracy: 0.9332 - loss: 0.1699 - precision: 0.8542 - recall: 0.5580
# Epoch 37/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.9326 - loss: 0.1938 - precision: 0.8655 - recall: 0.5331
# Epoch 38/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - accuracy: 0.9350 - loss: 0.1898 - precision: 0.8741 - recall: 0.5064
# Epoch 39/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.9381 - loss: 0.1817 - precision: 0.8112 - recall: 0.5277
# Epoch 40/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - accuracy: 0.9429 - loss: 0.1787 - precision: 0.8043 - recall: 0.6648
# Epoch 41/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.9275 - loss: 0.1952 - precision: 0.8958 - recall: 0.5454
# Epoch 42/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - accuracy: 0.9272 - loss: 0.1858 - precision: 0.7148 - recall: 0.4842
# Epoch 43/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - accuracy: 0.9421 - loss: 0.1502 - precision: 0.8442 - recall: 0.5917
# Epoch 44/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - accuracy: 0.9390 - loss: 0.1876 - precision: 0.8839 - recall: 0.5258
# Epoch 45/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - accuracy: 0.9285 - loss: 0.1941 - precision: 0.7649 - recall: 0.6846
# Epoch 46/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.9484 - loss: 0.1499 - precision: 0.9238 - recall: 0.6278
# Epoch 47/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - accuracy: 0.9468 - loss: 0.1735 - precision: 0.8027 - recall: 0.6044
# Epoch 48/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step - accuracy: 0.9511 - loss: 0.1495 - precision: 0.8779 - recall: 0.6845
# Epoch 49/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - accuracy: 0.9330 - loss: 0.1852 - precision: 0.8151 - recall: 0.5689
# Epoch 50/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 0.9416 - loss: 0.1645 - precision: 0.8225 - recall: 0.6499
# Epoch 51/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.9459 - loss: 0.1770 - precision: 0.9138 - recall: 0.6255
# Epoch 52/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step - accuracy: 0.9336 - loss: 0.2001 - precision: 0.8268 - recall: 0.6139
# Epoch 53/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - accuracy: 0.9311 - loss: 0.2023 - precision: 0.7681 - recall: 0.6346
# Epoch 54/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - accuracy: 0.9507 - loss: 0.1536 - precision: 0.8807 - recall: 0.6114
# Epoch 55/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - accuracy: 0.9531 - loss: 0.1651 - precision: 0.8872 - recall: 0.6620
# Epoch 56/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - accuracy: 0.9481 - loss: 0.1915 - precision: 0.8599 - recall: 0.6785
# Epoch 57/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - accuracy: 0.9500 - loss: 0.1705 - precision: 0.8496 - recall: 0.7456
# Epoch 58/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - accuracy: 0.9536 - loss: 0.1623 - precision: 0.9494 - recall: 0.5417
# Epoch 59/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 0.9511 - loss: 0.1626 - precision: 0.8700 - recall: 0.7393
# Epoch 60/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - accuracy: 0.9435 - loss: 0.1483 - precision: 0.8898 - recall: 0.5531
# Epoch 61/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - accuracy: 0.9489 - loss: 0.1853 - precision: 0.8057 - recall: 0.7125
# Epoch 62/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9372 - loss: 0.2129 - precision: 0.8154 - recall: 0.6057
# Epoch 63/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - accuracy: 0.9475 - loss: 0.1815 - precision: 0.8579 - recall: 0.7151
# Epoch 64/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - accuracy: 0.9562 - loss: 0.1423 - precision: 0.8532 - recall: 0.6884
# Epoch 65/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - accuracy: 0.9522 - loss: 0.1721 - precision: 0.9231 - recall: 0.6704
# Epoch 66/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - accuracy: 0.9715 - loss: 0.1336 - precision: 0.9200 - recall: 0.8097
# Epoch 67/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - accuracy: 0.9558 - loss: 0.1624 - precision: 0.8562 - recall: 0.7158
# Epoch 68/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - accuracy: 0.9579 - loss: 0.1625 - precision: 0.9209 - recall: 0.7260
# Epoch 69/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.9612 - loss: 0.1530 - precision: 0.9720 - recall: 0.6730
# Epoch 70/70
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - accuracy: 0.9499 - loss: 0.1552 - precision: 0.8701 - recall: 0.6532

# %%
final_tune.evaluate(X_test_scaled, y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8697 - loss: 0.3914 - precision: 0.4954 - recall: 0.4549
# [0.3634873330593109,
#  0.8740741014480591,
#  0.4848484992980957,
#  0.4848484992980957]

# %%
df_2025 = copy_df.loc[(copy_df["Year"] == 2025)]
df_2025
# Out:
#       Year  Seed  Round Finished   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  \
# 1079  2025     1             NaN  34  124.6   87.6   37.0   0.9830  52.7
# 1080  2025     1             NaN  34  127.4   90.8   36.6   0.9800  57.4
# 1081  2025     1             NaN  33  129.7   93.4   36.3   0.9775  55.7
# 1082  2025     1             NaN  34  127.0   94.0   33.0   0.9694  55.0
# 1083  2025     2             NaN  33  127.1   96.2   30.9   0.9606  56.3
# ...    ...   ...             ...  ..    ...    ...    ...      ...   ...
# 1142  2025    16             NaN  30  101.0  105.6   -4.6   0.3736  48.9
# 1143  2025    16             NaN  32  101.5  108.0   -6.5   0.3309  51.8
# 1144  2025    16             NaN  33   99.1  107.4   -8.3   0.2840  51.0
# 1145  2025    16             NaN  33  101.3  110.7   -9.4   0.2662  47.1
# 1146  2025    16             NaN  30   99.9  112.1  -12.2   0.2092  51.6
#
#       EFGD%  ...   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  \
# 1079   44.9  ...  49.0  43.9  39.8  30.9  34.5  43.1    62.2  11.6    30
# 1080   44.5  ...  58.0  43.4  37.7  30.9  45.4  37.9    66.5   9.4    31
# 1081   46.0  ...  56.1  47.2  36.8  29.2  40.6  34.8    68.5  12.5    28
# 1082   45.3  ...  56.4  45.9  35.5  29.6  43.6  37.3    70.3  11.1    30
# 1083   47.9  ...  59.7  48.8  35.0  30.8  46.2  35.1    75.4   9.8    25
# ...     ...  ...   ...   ...   ...   ...   ...   ...     ...   ...   ...
# 1142   47.5  ...  47.8  46.3  34.0  33.0  36.3  38.6    66.6  -7.8    19
# 1143   52.1  ...  51.1  53.1  35.1  33.6  44.8  35.7    64.2  -8.3    20
# 1144   48.0  ...  50.1  48.7  34.9  31.4  41.0  44.5    68.1  -8.2    21
# 1145   50.3  ...  45.4  50.4  32.9  33.4  42.9  39.5    68.4 -10.2    18
# 1146   51.3  ...  52.6  53.4  33.4  32.3  41.9  43.2    67.9 -12.2    13
#
#       Losses
# 1079       4
# 1080       3
# 1081       5
# 1082       4
# 1083       8
# ...      ...
# 1142      11
# 1143      12
# 1144      12
# 1145      15
# 1146      17
#
# [68 rows x 26 columns]

# %%
clean_2025 = df_2025.drop(columns='Round Finished')
clean_2025.head()
# Out:
#       Year  Seed   G  AdjOE  AdjDE  AdjNR  Barthag  EFG%  EFGD%   TOR  ...  \
# 1079  2025     1  34  124.6   87.6   37.0   0.9830  52.7   44.9  14.6  ...
# 1080  2025     1  34  127.4   90.8   36.6   0.9800  57.4   44.5  14.4  ...
# 1081  2025     1  33  129.7   93.4   36.3   0.9775  55.7   46.0  13.4  ...
# 1082  2025     1  34  127.0   94.0   33.0   0.9694  55.0   45.3  15.0  ...
# 1083  2025     2  33  127.1   96.2   30.9   0.9606  56.3   47.9  16.7  ...
#
#        2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  Wins  Losses
# 1079  49.0  43.9  39.8  30.9  34.5  43.1    62.2  11.6    30       4
# 1080  58.0  43.4  37.7  30.9  45.4  37.9    66.5   9.4    31       3
# 1081  56.1  47.2  36.8  29.2  40.6  34.8    68.5  12.5    28       5
# 1082  56.4  45.9  35.5  29.6  43.6  37.3    70.3  11.1    30       4
# 1083  59.7  48.8  35.0  30.8  46.2  35.1    75.4   9.8    25       8
#
# [5 rows x 25 columns]

# %%
# Create a StandardScaler instances
scaler_2025 = StandardScaler()

# Fit the StandardScaler
scaler25 = scaler.fit(clean_2025)

# Scale the data
scaled_2025 = scaler25.transform(clean_2025)

# %%
#Use model to predict 2025 Elite 8 probabilities
prediction_2025 = final_tune.predict(scaled_2025)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
#Create new Dataframe to Pull team names From
name_df = bracket_df.copy()

names_2025 = name_df.loc[(bracket_df["Year"] == 2025)]
names_2025.head(68)
# Out:
#       Year  Seed            School  Round Finished  Conf   G    Rec  AdjOE  \
# 1079  2025     1           Houston             NaN   B12  34   30–4  124.6
# 1080  2025     1              Duke             NaN   ACC  34   31–3  127.4
# 1081  2025     1            Auburn             NaN   SEC  33   28–5  129.7
# 1082  2025     1           Florida             NaN   SEC  34   30–4  127.0
# 1083  2025     2           Alabama             NaN   SEC  33   25–8  127.1
# ...    ...   ...               ...             ...   ...  ..    ...    ...
# 1142  2025    16  SIU Edwardsville             NaN   OVC  30  19–11  101.0
# 1143  2025    16          American             NaN   Pat  32  20–12  101.5
# 1144  2025    16  Mount St. Mary's             NaN  MAAC  33  21–12   99.1
# 1145  2025    16       Alabama St.             NaN  SWAC  33  18–15  101.3
# 1146  2025    16     Saint Francis             NaN   NEC  30  13–17   99.9
#
#       AdjDE  AdjNR  ...   2P%  2P%D   3P%  3P%D   3PR  3PRD  Adj T.   WAB  \
# 1079   87.6   37.0  ...  49.0  43.9  39.8  30.9  34.5  43.1    62.2  11.6
# 1080   90.8   36.6  ...  58.0  43.4  37.7  30.9  45.4  37.9    66.5   9.4
# 1081   93.4   36.3  ...  56.1  47.2  36.8  29.2  40.6  34.8    68.5  12.5
# 1082   94.0   33.0  ...  56.4  45.9  35.5  29.6  43.6  37.3    70.3  11.1
# 1083   96.2   30.9  ...  59.7  48.8  35.0  30.8  46.2  35.1    75.4   9.8
# ...     ...    ...  ...   ...   ...   ...   ...   ...   ...     ...   ...
# 1142  105.6   -4.6  ...  47.8  46.3  34.0  33.0  36.3  38.6    66.6  -7.8
# 1143  108.0   -6.5  ...  51.1  53.1  35.1  33.6  44.8  35.7    64.2  -8.3
# 1144  107.4   -8.3  ...  50.1  48.7  34.9  31.4  41.0  44.5    68.1  -8.2
# 1145  110.7   -9.4  ...  45.4  50.4  32.9  33.4  42.9  39.5    68.4 -10.2
# 1146  112.1  -12.2  ...  52.6  53.4  33.4  32.3  41.9  43.2    67.9 -12.2
#
#       Wins  Losses
# 1079    30       4
# 1080    31       3
# 1081    28       5
# 1082    30       4
# 1083    25       8
# ...    ...     ...
# 1142    19      11
# 1143    20      12
# 1144    21      12
# 1145    18      15
# 1146    13      17
#
# [68 rows x 29 columns]

# %%
#Turn nested list into a flattened list
flattened_prediction = []
for sublist in prediction_2025:
    for item in sublist:
        flattened_prediction.append(item)

#sorted_predictions = sorted(flattened_prediction, reverse=True)

# %%
#Create Dataframe with Names and Predictions

#Create dictionary of Schools and Prediction
data = {
    'School': names_2025['School'],
    'Probability': flattened_prediction
}

#Create DataFrame
df = pd.DataFrame(data)

#Sort Dataframe
df_sorted = df.sort_values(by='Probability', ascending=False)

df_sorted.head(22)
# Out:
#             School  Probability
# 1083       Alabama     0.980465
# 1085    Texas Tech     0.919264
# 1092    St. John's     0.907757
# 1080          Duke     0.864571
# 1112     Creighton     0.631216
# 1086      Iowa St.     0.631019
# 1079       Houston     0.536144
# 1099     Texas A&M     0.486076
# 1089       Gonzaga     0.462146
# 1087       Arizona     0.387107
# 1095        Kansas     0.371604
# 1091     Wisconsin     0.304638
# 1094      Kentucky     0.245311
# 1103  Saint Mary's     0.241569
# 1081        Auburn     0.214967
# 1082       Florida     0.197931
# 1096      Illinois     0.180158
# 1100    Louisville     0.156804
# 1104      Michigan     0.085180
# 1090  Michigan St.     0.075278
# 1111   Connecticut     0.069839
# 1124  UC San Diego     0.054286

# %%
df_sorted2 = df_sorted.sort_values(by='Probability', ascending=False)

sorted_school = df_sorted2['School']
sorted_probability = df_sorted2['Probability']

plt.figure(figsize=(25,8))
plt.bar(sorted_school, sorted_probability)

plt.xticks(rotation=90)

plt.xlim(-0.75, len(sorted_school))
plt.ylim(0, max(sorted_probability)+.05)

plt.title("Likelihood of Making Elite 8")
plt.xlabel("School")
plt.ylabel("Model Probability to make the Elite 8")


plt.show()
